# %%
import os
os.environ['KMP_DUPLICATE_LIB_OK'] = 'True'

# %%
import pandas as pd
df = pd.read_csv("creditcard.csv") 
df.shape
# Out:
# (284807, 31)

# %%
df.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
df.Class.value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.countplot(x='Class', data=df)
plt.title('Class Distributions \n (0: No Fraud || 1: Fraud)', fontsize=14)
plt.show()

# %%
float(df.isnull().sum().max())
# Out:
# 0.0

# %%
df.sort_index(axis=1).head(3)
# Out:
#    Amount  Class  Time        V1       V10       V11       V12       V13  \
# 0  149.62      0   0.0 -1.359807  0.090794 -0.551600 -0.617801 -0.991390
# 1    2.69      0   0.0  1.191857 -0.166974  1.612727  1.065235  0.489095
# 2  378.66      0   1.0 -1.358354  0.207643  0.624501  0.066084  0.717293
#
#         V14       V15  ...       V26       V27       V28        V3        V4  \
# 0 -0.311169  1.468177  ... -0.189115  0.133558 -0.021053  2.536347  1.378155
# 1 -0.143772  0.635558  ...  0.125895 -0.008983  0.014724  0.166480  0.448154
# 2 -0.165946  2.345865  ... -0.139097 -0.055353 -0.059752  1.773209  0.379780
#
#          V5        V6        V7        V8        V9
# 0 -0.338321  0.462388  0.239599  0.098698  0.363787
# 1  0.060018 -0.082361 -0.078803  0.085102 -0.255425
# 2 -0.503198  1.800499  0.791461  0.247676 -1.514654
#
# [3 rows x 31 columns]

# %%
df.sort_index(axis=1).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Amount  284807 non-null  float64
#  1   Class   284807 non-null  int64
#  2   Time    284807 non-null  float64
#  3   V1      284807 non-null  float64
#  4   V10     284807 non-null  float64
#  5   V11     284807 non-null  float64
#  6   V12     284807 non-null  float64
#  7   V13     284807 non-null  float64
#  8   V14     284807 non-null  float64
#  9   V15     284807 non-null  float64
#  10  V16     284807 non-null  float64
#  11  V17     284807 non-null  float64
#  12  V18     284807 non-null  float64
#  13  V19     284807 non-null  float64
#  14  V2      284807 non-null  float64
#  15  V20     284807 non-null  float64
#  16  V21     284807 non-null  float64
#  17  V22     284807 non-null  float64
#  18  V23     284807 non-null  float64
#  19  V24     284807 non-null  float64
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(12,8))
sns.heatmap(df.corr(),cmap="coolwarm_r",annot=False)
# Out:
# <Axes: >

# %%
df.min()
# Out:
# Time        0.000000
# V1        -56.407510
# V2        -72.715728
# V3        -48.325589
# V4         -5.683171
# V5       -113.743307
# V6        -26.160506
# V7        -43.557242
# V8        -73.216718
# V9        -13.434066
# V10       -24.588262
# V11        -4.797473
# V12       -18.683715
# V13        -5.791881
# V14       -19.214325
# V15        -4.498945
# V16       -14.129855
# V17       -25.162799
# V18        -9.498746
# V19        -7.213527
# V20       -54.497720
# V21       -34.830382
# V22       -10.933144
# V23       -44.807735
# V24        -2.836627
# V25       -10.295397
# V26        -2.604551
# V27       -22.565679
# V28       -15.430084
# Amount      0.000000
# Class       0.000000
# dtype: float64

# %%
df.max()
# Out:
# Time      172792.000000
# V1             2.454930
# V2            22.057729
# V3             9.382558
# V4            16.875344
# V5            34.801666
# V6            73.301626
# V7           120.589494
# V8            20.007208
# V9            15.594995
# V10           23.745136
# V11           12.018913
# V12            7.848392
# V13            7.126883
# V14           10.526766
# V15            8.877742
# V16           17.315112
# V17            9.253526
# V18            5.041069
# V19            5.591971
# V20           39.420904
# V21           27.202839
# V22           10.503090
# V23           22.528412
# V24            4.584549
# V25            7.519589
# V26            3.517346
# V27           31.612198
# V28           33.847808
# Amount     25691.160000
# Class          1.000000
# dtype: float64

# %%
sns.histplot(df['Time'],kde=False)
# Out:
# <Axes: xlabel='Time', ylabel='Count'>

# %%
sns.kdeplot(df['Time'])
# Out:
# <Axes: xlabel='Time', ylabel='Density'>

# %%
sns.distplot(df['Amount'],kde=False)
# Out:
# C:\Users\bosea\AppData\Local\Temp\ipykernel_14120\2882487679.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Amount'],kde=False)
# <Axes: xlabel='Amount'>

# %%
sns.kdeplot(df['Amount'])
# Out:
# <Axes: xlabel='Amount', ylabel='Density'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
fig,ax=plt.subplots(1,2, figsize=(14,4))
sns.distplot(df['Amount'],ax=ax[0],color='r')
ax[0].set_title('Distribution of Transaction Amount',fontsize=14)
sns.distplot(df['Time'],ax=ax[1],color='b')
ax[1].set_title('Distribution of Transaction Time',fontsize=14)
plt.show()
# Out:
# C:\Users\bosea\AppData\Local\Temp\ipykernel_14120\1256087994.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Amount'],ax=ax[0],color='r')
# C:\Users\bosea\AppData\Local\Temp\ipykernel_14120\1256087994.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
df[['Time','Amount']].groupby(['Time']).head()
# Out:
#             Time  Amount
# 0            0.0  149.62
# 1            0.0    2.69
# 2            1.0  378.66
# 3            1.0  123.50
# 4            2.0   69.99
# ...          ...     ...
# 284802  172786.0    0.77
# 284803  172787.0   24.79
# 284804  172788.0   67.88
# 284805  172788.0   10.00
# 284806  172792.0  217.00
#
# [279146 rows x 2 columns]

# %%
df[['Time','Amount']].groupby(['Time']).sum().plot()
# Out:
# <Axes: xlabel='Time'>

# %%
sns.scatterplot(x='Time', y='Amount', 
                data=df, hue='Class', 
                size_order=[1, 0], size='Class')
# Out:
# <Axes: xlabel='Time', ylabel='Amount'>

# %%
float(df.Amount.min()) , float(df.Amount.max())
# Out:
# (0.0, 25691.16)

# %%
df[df['Amount']==0].shape
# Out:
# (1825, 31)

# %%
df[df["Amount"]==0]["Class"].value_counts()
# Out:
# Class
# 0    1798
# 1      27
# Name: count, dtype: int64

# %%
f_df=df[df['Class']==1]
n_df=df[df['Class']==0]
(f_df.shape, n_df.shape)
# Out:
# ((492, 31), (284315, 31))

# %%
float(f_df.Amount.min()) , float(f_df.Amount.max())
# Out:
# (0.0, 2125.87)

# %%
fig, ax = plt.subplots(1,2, figsize=(14,4))

sns.distplot(n_df['Amount'], kde=False, ax=ax[0], color='r')
ax[0].set_title('Non-Fraudulent:Transaction Amount' , fontsize=14)

sns.histplot(f_df['Amount'], kde=False, ax=ax[1], color='b')
ax[1].set_title('Fraudulent:Transaction Amount' , fontsize=14)

plt.show()
# Out:
# C:\Users\bosea\AppData\Local\Temp\ipykernel_14120\846355650.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(n_df['Amount'], kde=False, ax=ax[0], color='r')

# %%
fig, ax = plt.subplots(1,2, figsize=(14,4))

sns.kdeplot(n_df['Amount'], ax=ax[0], color='r')
ax[0].set_title('Non-Fraudulent:Transaction Amount(KDE)' , fontsize=14)

sns.kdeplot(f_df['Amount'], ax=ax[1], color='b')
ax[1].set_title('Fraudulent:Transaction Amount(KDE)' , fontsize=14)

plt.show()

# %%
fig, ax = plt.subplots(1,2, figsize=(14,4))

sns.histplot(n_df['Time'], kde=False, ax=ax[0], color='r')
ax[0].set_title('Non-Fraudulent:Transaction Time' , fontsize=14)

sns.histplot(f_df['Time'], kde=False, ax=ax[1], color='b')
ax[1].set_title('Fraudulent:Transaction Time' , fontsize=14)

plt.show()

# %%
fig, ax = plt.subplots(1,2, figsize=(14,4))

sns.kdeplot(n_df['Time'], ax=ax[0], color='r')
ax[0].set_title('Non-Fraudulent:Transaction Time(KDE)' , fontsize=14)

sns.kdeplot(f_df['Time'], ax=ax[1], color='b')
ax[1].set_title('Fraudulent:Transaction Time(KDE)' , fontsize=14)

plt.show()

# %%
n_df[['Time','Amount']].groupby(['Time']).sum().plot()
# Out:
# <Axes: xlabel='Time'>

# %%
f_df[['Time','Amount']].groupby(['Time']).sum().plot()
# Out:
# <Axes: xlabel='Time'>

# %%
print("Entire Dataset: " + str(df.Amount.sum()))
print("Non-Fraudulent Dataset:" + str(n_df.Amount.sum()))
print("Fraudulent Dataset: " + str(f_df.Amount.sum()))
# Out:
# Entire Dataset: 25162590.009999998
# Non-Fraudulent Dataset:25102462.04
# Fraudulent Dataset: 60127.97

# %%
df.drop(df[df.Amount==0].index, inplace=True)
f_df=df[df['Class']==1]
n_df=df[df['Class']==0]
(df.shape, f_df.shape, n_df.shape)
# Out:
# ((282982, 31), (465, 31), (282517, 31))

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(12,8))
sns.heatmap(df.corr(),cmap="coolwarm_r",annot=False)
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# Function to compare KDE plots
def compare_kde(col1, col2, name):
    fig, ax = plt.subplots(2, 2, figsize=(16, 7))
    sns.kdeplot(df[df['Class'] == 0]['Amount'], ax=ax[0][0], color='r')
    ax[0][0].set_title('Non-Fraudulent: Transaction Amount (Original)', fontsize=12)
    sns.kdeplot(df[df['Class'] == 1]['Time'], ax=ax[0][1], color='b')
    ax[0][1].set_title('Fraudulent: Transaction Time (Original)', fontsize=12)
    print("\n \n")
    sns.kdeplot(df[df['Class'] == 0][col1], ax=ax[1][0], color='r')
    ax[1][0].set_title('Non-Fraudulent: Transaction Amount (' + name + ')', fontsize=12)
    sns.kdeplot(df[df['Class'] == 1][col2], ax=ax[1][1], color='b')
    ax[1][1].set_title('Fraudulent: Transaction Time (' + name + ')', fontsize=12)
    plt.subplots_adjust(wspace=0.3, hspace=0.4)
    plt.show()

# %%
from sklearn.preprocessing import StandardScaler
# Scaling the features
std_scaler = StandardScaler()
df['scaled_amount'] = std_scaler.fit_transform(df['Amount'].values.reshape(-1, 1))
df['scaled_time'] = std_scaler.fit_transform(df['Time'].values.reshape(-1, 1))
# Corrected function call
compare_kde('scaled_amount', 'scaled_time', 'StandardScaler')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(12,8))
sns.heatmap(df.corr(),cmap='coolwarm_r', annot=False)
# Out:
# <Axes: >

# %%
from sklearn.preprocessing import RobustScaler
# Scaling the features
rob_scaler = RobustScaler()
df['robust_amount'] = rob_scaler.fit_transform(df['Amount'].values.reshape(-1, 1))
df['robust_time'] = rob_scaler.fit_transform(df['Time'].values.reshape(-1, 1))
# Corrected function call
compare_kde('robust_amount', 'robust_time', 'RobustScaler')

# %%
from sklearn.preprocessing import PowerTransformer
# Scaling the features
p_trans = PowerTransformer()
df['ptrans_amount'] = p_trans.fit_transform(df['Amount'].values.reshape(-1, 1))
df['ptrans_time'] = p_trans.fit_transform(df['Time'].values.reshape(-1, 1))
# Corrected function call
compare_kde('ptrans_amount', 'ptrans_time', 'PowerTransformer')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(12,8))
sns.heatmap(df.corr(),cmap='coolwarm_r', annot=False)
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(12,10))
sns.heatmap(df[["scaled_amount","robust_amount" ,
                "ptrans_amount", "Amount", "Class" ,
                "Time","scaled_time" , "robust_time",
                "ptrans_time" ]].corr(),cmap='coolwarm_r' , annot=True)
# Out:
# <Axes: >

# %%
df[["Amount","scaled_amount","robust_amount" ,
                "ptrans_amount" ]].describe().T
# Out:
#                   count          mean         std       min       25%  \
# Amount         282982.0  8.891940e+01  250.824374  0.010000  5.990000
# scaled_amount  282982.0  2.892570e-17    1.000002 -0.354469 -0.330628
# robust_amount  282982.0  9.225024e-01    3.483188 -0.312179 -0.229135
# ptrans_amount  282982.0  2.470737e-16    1.000002 -2.050775 -0.733013
#
#                      50%        75%           max
# Amount         22.490000  78.000000  25691.160000
# scaled_amount  -0.264845  -0.043534    102.072560
# robust_amount   0.000000   0.770865    356.459797
# ptrans_amount   0.030784   0.750683      3.649005

# %%
df[["Time","scaled_time" , "robust_time",
                "ptrans_time"  ]].describe().T
# Out:
#                 count          mean           std       min           25%  \
# Time         282982.0  9.484896e+04  47482.459589  0.000000  54251.250000
# scaled_time  282982.0 -1.349866e-16      1.000002 -1.997561     -0.855006
# robust_time  282982.0  1.191536e-01      0.557879 -0.995242     -0.357835
# ptrans_time  282982.0 -1.928380e-16      1.000002 -2.436283     -0.809483
#
#                       50%            75%            max
# Time         84707.500000  139363.750000  172792.000000
# scaled_time     -0.213584       0.937501       1.641515
# robust_time      0.000000       0.642165       1.034918
# ptrans_time     -0.143207       0.928790       1.534947

# %%
from sklearn.model_selection import train_test_split
import numpy as np

#Original percentage of No frauds and Frauds in Data Set
print('No Frauds',round(df['Class'].value_counts()[0]/len(df)*100 , 2), '% of the dataset' )
print('Frauds',round(df['Class'].value_counts()[1]/len(df)*100 , 2), '% of the dataset' )

# Separate features and target variable
X = df.drop('Class', axis=1)
y = df['Class']

#Train Test Split
X_train , X_test , y_train, y_test = train_test_split(X,y, test_size=0.2, random_state=2)

#See if both the train and test label distribution are similarly distributed
train_unique_label, train_counts_label = np.unique(y_train, return_counts=True)
test_unique_label, test_counts_label = np.unique(y_test, return_counts=True)

print('\n Label Distribution: \n')
print(train_counts_label / len(y_train))
print(test_counts_label / len(y_test))

print('\nTrain:')
print('No Frauds' ,round(len(y_train[y_train==0])/len(X_train)* 100,2) , '% of the dataset')
print('Frauds' ,round(len(y_train[y_train==1])/len(X_train)* 100,2) , '% of the dataset')

print('\nTest:')
print('No Frauds' ,round(len(y_test[y_test==0])/len(X_test)* 100,2) , '% of the dataset')
print('Frauds' ,round(len(y_test[y_test==1])/len(X_test)* 100,2) , '% of the dataset')
# Out:
# No Frauds 99.84 % of the dataset
# Frauds 0.16 % of the dataset
#
#  Label Distribution:
#
# [0.99830377 0.00169623]
# [0.99856883 0.00143117]
#
# Train:
# No Frauds 99.83 % of the dataset
# Frauds 0.17 % of the dataset
#
# Test:
# No Frauds 99.86 % of the dataset
# Frauds 0.14 % of the dataset

# %%
from sklearn.model_selection import StratifiedKFold
import numpy as np

#Original percentage of No frauds and Frauds in Data Set
print('No Frauds',round(df['Class'].value_counts()[0]/len(df)*100 , 2), '% of the dataset' )
print('Frauds',round(df['Class'].value_counts()[1]/len(df)*100 , 2), '% of the dataset' )

# Separate features and target variable
X = df.drop('Class', axis=1)
y = df['Class']

# creating an instance of the StratifiedKFold class describing how many folds etc.
skf = StratifiedKFold(n_splits=10, shuffle=False, random_state=None)

#Train Test Split
for train_index, test_index in skf.split(X, y):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

#See if both the train and test label distribution are similarly distributed
train_unique_label, train_counts_label = np.unique(y_train, return_counts=True)
test_unique_label, test_counts_label = np.unique(y_test, return_counts=True)

print('\n Label Distribution: \n')
print(train_counts_label / len(y_train))
print(test_counts_label / len(y_test))

print('\nTrain:')
print('No Frauds' ,round(len(y_train[y_train==0])/len(X_train)* 100,2) , '% of the dataset')
print('Frauds' ,round(len(y_train[y_train==1])/len(X_train)* 100,2) , '% of the dataset')

print('\nTest:')
print('No Frauds' ,round(len(y_test[y_test==0])/len(X_test)* 100,2) , '% of the dataset')
print('Frauds' ,round(len(y_test[y_test==1])/len(X_test)* 100,2) , '% of the dataset')
# Out:
# No Frauds 99.84 % of the dataset
# Frauds 0.16 % of the dataset
#
#  Label Distribution:
#
# [0.99835875 0.00164125]
# [0.99833911 0.00166089]
#
# Train:
# No Frauds 99.84 % of the dataset
# Frauds 0.16 % of the dataset
#
# Test:
# No Frauds 99.83 % of the dataset
# Frauds 0.17 % of the dataset

# %%
train_df=X_train.copy()
train_df['Class'] = y_train
train_df.shape
# Out:
# (254684, 37)

# %%
train_df['Class'].value_counts()
# Out:
# Class
# 0    254266
# 1       418
# Name: count, dtype: int64

# %%
import seaborn as sns

# Class count
count_class_0, count_class_1 = train_df.Class.value_counts()

# Divide by class
train_df_0 = train_df[train_df['Class'] == 0]  
train_df_1 = train_df[train_df['Class'] == 1] 

train_df_0_under = train_df_0.sample(count_class_1)
train_df_under = pd.concat([train_df_0_under, train_df_1], axis=0)

print('Random under-sampling:')
print(train_df_under.Class.value_counts())

sns.countplot(x='Class', data=train_df_under)
# Out:
# Random under-sampling:
# Class
# 0    418
# 1    418
# Name: count, dtype: int64
# <Axes: xlabel='Class', ylabel='count'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(12,8))
sns.heatmap(train_df_under.corr(),cmap="coolwarm_r",annot=False)
# Out:
# <Axes: >

# %%
print(train_df_under.corr()['Class'].sort_values(ascending=False))
# Out:
# Class            1.000000
# V4               0.706611
# V11              0.689202
# V2               0.515251
# V19              0.308569
# V20              0.185875
# V21              0.137053
# robust_amount    0.122217
# scaled_amount    0.122217
# Amount           0.122217
# V27              0.098310
# V28              0.073711
# V8               0.059782
# V26              0.016354
# V22              0.016197
# V25              0.009306
# V15             -0.017251
# V23             -0.017685
# ptrans_amount   -0.029426
# V13             -0.031327
# V24             -0.060458
# robust_time     -0.160962
# scaled_time     -0.160962
# Time            -0.160962
# ptrans_time     -0.163820
# V6              -0.395264
# V5              -0.414112
# V1              -0.460278
# V7              -0.498680
# V18             -0.504174
# V9              -0.553408
# V3              -0.575428
# V17             -0.579735
# V16             -0.623972
# V10             -0.632976
# ...

# %%
from imblearn.over_sampling import SMOTE
import pandas as pd
import seaborn as sns

# Initialize SMOTE
sm = SMOTE()

# Use fit_resample instead of fit_sample
X_sm, y_sm = sm.fit_resample(X_train, y_train)

# Create a new DataFrame for the resampled data
train_df_sm = pd.DataFrame(X_sm, columns=X_train.columns)  
train_df_sm['Class'] = y_sm

# Print the class distribution after SMOTE
print('SMOTE over sampling:')
print(train_df_sm['Class'].value_counts())

# Plot the count of each class
sns.countplot(x='Class', data=train_df_sm)
# Out:
# SMOTE over sampling:
# Class
# 0    254266
# 1    254266
# Name: count, dtype: int64
# <Axes: xlabel='Class', ylabel='count'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(12,8))
sns.heatmap(train_df_sm.corr(),cmap="coolwarm_r",annot=False)
# Out:
# <Axes: >

# %%
print(train_df_sm.corr()['Class'].sort_values(ascending=False))
# Out:
# Class            1.000000
# V4               0.737109
# V11              0.718098
# V2               0.546560
# V19              0.337830
# V20              0.164987
# V21              0.155557
# V27              0.095880
# V28              0.087202
# V8               0.064116
# Amount           0.043986
# robust_amount    0.043986
# scaled_amount    0.043986
# V26              0.032122
# V25              0.031280
# V22             -0.004553
# V23             -0.008027
# V13             -0.032053
# V15             -0.066600
# V24             -0.081177
# ptrans_amount   -0.098325
# ptrans_time     -0.188131
# Time            -0.188877
# scaled_time     -0.188877
# robust_time     -0.188877
# V6              -0.410640
# V5              -0.437395
# V1              -0.477785
# V18             -0.529873
# V7              -0.537544
# V9              -0.591840
# V3              -0.595834
# V17             -0.613244
# V16             -0.652035
# V10             -0.672315
# ...

# %%
#Data Preparation
col_set1=["robust_amount" , "robust_time" , "V2" , "V4" , "V10" , "V11", "V12" , "V14", "V16" , "V17" , "V19"]
col_set2=["ptrans_amount" , "ptrans_time" , "V2" , "V4" , "V10" , "V11", "V12" , "V14", "V16" , "V17" , "V19"]

# %%
#Train SMOTE-Robust sampled dataset 

X_train_smote_robust = train_df_sm[col_set1]
y_train_smote_robust = train_df_sm["Class"]

#Train SMOTE-Power transformer sampled dataset
X_train_smote_power = train_df_sm[col_set2]
y_train_smote_power = train_df_sm["Class"]

# %%
#Train Random Undersampled-Robust  dataset 

X_train_under_robust = train_df_under[col_set1]
y_train_under_robust = train_df_under["Class"]

#Train Random Undersampled-Power transformer sampled dataset
X_train_under_power = train_df_under[col_set2]
y_train_under_power = train_df_under["Class"]

# %%
#dataset to use in a loop to train

data =[
  [X_train_smote_robust,y_train_smote_robust , "SMOTE-Robust Scaling"],
  [X_train_smote_power,y_train_smote_power, "SMOTE-Power Transformer"],
    [X_train_under_robust,y_train_under_robust,"Under Sampling-Robust Scaling"],
    [X_train_under_power,y_train_under_power ,"Under Sampling-Power Transformer" ]
]

# %%
#Classifier Librariers

from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier

classifiers = {
    "Random Forest Classifiers" : RandomForestClassifier(n_estimators=100, random_state=42),
    "Gradient Boosting Classifier" : GradientBoostingClassifier(n_estimators=100, random_state=42)
}

# %%
#from sklearn.model_selection import cross_val_score

#print(f"SMOTE-Power Transformer dataset shape: {X_train_smote_power.shape}, {y_train_smote_power.shape}")

#for key, classifier in classifiers.items():
    #print(f"Running classifier: {key}")  # Debugging print
    #classifier.fit(X_train_smote_power, y_train_smote_power)  
    #training_score = cross_val_score(classifier, X_train_smote_power, y_train_smote_power, cv=5)
    #print("Classifiers:", classifier.__class__.__name__, "has a training score of", round(training_score.mean(), 2) * 100, "% accuracy score")

# %%
from sklearn.model_selection import cross_val_score
for X, y, name in data:
    print("\n\n" + name + ":\n")
    for key, classifier in classifiers.items():
        classifier.fit(X, y)
        training_score = cross_val_score(classifier, X, y, cv=5)
        print("Classifiers:", classifier.__class__.__name__, 
              "has a training score of", 
              round(training_score.mean(), 2) * 100, "% accuracy score")
# Out:
# SMOTE-Robust Scaling:
#
# Classifiers: RandomForestClassifier has a training score of 82.0 % accuracy score
# Classifiers: GradientBoostingClassifier has a training score of 80.0 % accuracy score
#
#
# SMOTE-Power Transformer:
#
# Classifiers: RandomForestClassifier has a training score of 82.0 % accuracy score
# Classifiers: GradientBoostingClassifier has a training score of 79.0 % accuracy score
#
#
# Under Sampling-Robust Scaling:
#
# Classifiers: RandomForestClassifier has a training score of 93.0 % accuracy score
# Classifiers: GradientBoostingClassifier has a training score of 90.0 % accuracy score
#
#
# Under Sampling-Power Transformer:
#
# Classifiers: RandomForestClassifier has a training score of 93.0 % accuracy score
# Classifiers: GradientBoostingClassifier has a training score of 90.0 % accuracy score

# %%
X_test_robust = X_test[col_set1]
X_test_power = X_test[col_set2]

# %%
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.metrics import roc_curve, auc

# Initialize classifiers
RFC_Under_Sampling_Power = RandomForestClassifier(n_estimators=100, random_state=42)
RFC_SMOTE_Robust = RandomForestClassifier(n_estimators=100, random_state=42)
GBC_Under_Sampling_Power = GradientBoostingClassifier(n_estimators=100, random_state=42)
GBC_SMOTE_Robust = GradientBoostingClassifier(n_estimators=100, random_state=42)

# Train classifiers
RFC_SMOTE_Robust.fit(X_train_smote_robust, y_train_smote_robust)
RFC_Under_Sampling_Power.fit(X_train_smote_power, y_train_smote_power)
GBC_SMOTE_Robust.fit(X_train_smote_robust, y_train_smote_robust)
GBC_Under_Sampling_Power.fit(X_train_smote_power, y_train_smote_power)

# Compute ROC curve and AUC for RandomForestClassifier for SMOTE Robust
RFCSMR_fpr, RFCSMR_tpr, RFCSMR_threshold = roc_curve(y_test, RFC_SMOTE_Robust.predict_proba(X_test_robust)[:,1])
RFCSMR_auc = auc(RFCSMR_fpr, RFCSMR_tpr)

# Compute ROC curve and AUC for RandomForestClassifier for Under Smapling
RFCUS_fpr, RFCUS_tpr, RFCUS_threshold = roc_curve(y_test, RFC_Under_Sampling_Power.predict_proba(X_test_power)[:,1])
RFCUS_auc = auc(RFCUS_fpr, RFCUS_tpr)

# Compute ROC curve and AUC for GradientBoostingClassifier for SMOTE Robust
GBCSMR_fpr, GBCSMR_tpr, GBCSMR_threshold = roc_curve(y_test, GBC_SMOTE_Robust.predict_proba(X_test_robust)[:,1])
GBCSMR_auc = auc(GBCSMR_fpr, GBCSMR_tpr)

# Compute ROC curve and AUC for RandomForestClassifier for Under Smapling
GBCUS_fpr, GBCUS_tpr, GBCUS_threshold = roc_curve(y_test, GBC_Under_Sampling_Power.predict_proba(X_test_power)[:,1])
GBCUS_auc = auc(GBCUS_fpr, GBCUS_tpr)

# Plot ROC curves
plt.figure(figsize=(16, 8))
plt.title('ROC Curve \n Top 2 Classifiers for SMOTE Robust and Power Transformer', fontsize=4)
plt.plot(RFCSMR_fpr, RFCSMR_tpr, color='blue', label=f'Random Forest SMOTE Robust (AUC = {RFCSMR_auc:.2f})')
plt.plot(GBCSMR_fpr, GBCSMR_tpr, color='red', label=f'Gradient Boosting SMOTE Robust (AUC = {GBCSMR_auc:.2f})')
plt.plot(RFCUS_fpr, RFCUS_tpr, color='yellow', label=f'Random Forest Under Sampling Power (AUC = {RFCUS_auc:.2f})')
plt.plot(GBCUS_fpr, GBCUS_tpr, color='orange', label=f'Gradient Boosting Under Sampling Power (AUC = {GBCUS_auc:.2f})')
plt.plot([0, 1], [0, 1], color='gray', linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.annotate('Minimum ROC score of 50%' , xy=(0.5,0.5) , xytext=(0.6,0.3),
           arrowprops=dict(facecolor='#6E726D' , shrink=0.05),)
plt.legend()
plt.show()

# %%
from sklearn.metrics import roc_auc_score

print("ROC Accuracy Score\n")
print('RFC_Under_Sampling_Power:' , roc_auc_score(y_test, 
    RFC_Under_Sampling_Power.predict_proba(X_test_power)[:,1]))

print('GBC_Under_Sampling_Power:' , roc_auc_score(y_test, 
     GBC_Under_Sampling_Power.predict_proba(X_test_power)[:,1]))

print('GBC_SMOTE_Robust:' , roc_auc_score(y_test, 
      GBC_SMOTE_Robust.predict_proba(X_test_robust)[:,1]))

print('ROC_SMOTE_Robust:' , roc_auc_score(y_test, 
       RFC_SMOTE_Robust.predict_proba(X_test_robust)[:,1]))
# Out:
# ROC Accuracy Score
#
# RFC_Under_Sampling_Power: 0.9607598149415912
# GBC_Under_Sampling_Power: 0.9705741916874342
# GBC_SMOTE_Robust: 0.9696888906963941
# ROC_SMOTE_Robust: 0.9084159702123141

# %%
from sklearn.metrics import ConfusionMatrixDisplay, confusion_matrix
import matplotlib.pyplot as plt
cm = confusion_matrix(y_test, RFC_SMOTE_Robust.predict(X_test_robust))
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=[0, 1])
disp.plot(cmap=plt.cm.Blues)
plt.show()

# %%
from sklearn.metrics import ConfusionMatrixDisplay, confusion_matrix
import matplotlib.pyplot as plt
cm = confusion_matrix(y_test, RFC_Under_Sampling_Power.predict(X_test_power))
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=[0, 1])
disp.plot(cmap=plt.cm.Blues)
plt.show()

# %%
from sklearn.metrics import ConfusionMatrixDisplay, confusion_matrix
import matplotlib.pyplot as plt
cm = confusion_matrix(y_test, GBC_SMOTE_Robust.predict(X_test_robust))
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=[0, 1])
disp.plot(cmap=plt.cm.Blues)
plt.show()

# %%
from sklearn.metrics import ConfusionMatrixDisplay, confusion_matrix
import matplotlib.pyplot as plt
cm = confusion_matrix(y_test, GBC_Under_Sampling_Power.predict(X_test_power))
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=[0, 1])
disp.plot(cmap=plt.cm.Blues)
plt.show()

# %%
from sklearn.metrics import classification_report

print('RFC_SMOTE_Robust:')
print(classification_report(y_test, RFC_SMOTE_Robust.predict(X_test_robust)))

print('GBC_SMOTE_Robust:')
print(classification_report(y_test, GBC_SMOTE_Robust.predict(X_test_robust)))

print('GBC_Under_Sampling_Power:')
print(classification_report(y_test, GBC_Under_Sampling_Power.predict(X_test_power)))

print('RFC_Under_Sampling_Power:')
print(classification_report(y_test, RFC_Under_Sampling_Power.predict(X_test_power)))
# Out:
# RFC_SMOTE_Robust:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     28251
#            1       0.89      0.68      0.77        47
#
#     accuracy                           1.00     28298
#    macro avg       0.94      0.84      0.89     28298
# weighted avg       1.00      1.00      1.00     28298
#
# GBC_SMOTE_Robust:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     28251
#            1       0.23      0.77      0.35        47
#
#     accuracy                           1.00     28298
#    macro avg       0.62      0.88      0.68     28298
# weighted avg       1.00      1.00      1.00     28298
#
# GBC_Under_Sampling_Power:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     28251
#            1       0.22      0.77      0.34        47
#
#     accuracy                           0.99     28298
# ...

# %%
from sklearn.metrics import classification_report

print('RFC_SMOTE_Robust:')
print(classification_report(y_test, RFC_SMOTE_Robust.predict(X_test_robust)))

print('GBC_SMOTE_Robust:')
print(classification_report(y_test, GBC_SMOTE_Robust.predict(X_test_robust)))

print('GBC_Under_Sampling_Power:')
print(classification_report(y_test, GBC_Under_Sampling_Power.predict(X_test_power)))

print('RFC_Under_Sampling_Power:')
print(classification_report(y_test, RFC_Under_Sampling_Power.predict(X_test_power)))
# Out:
# RFC_SMOTE_Robust:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     28251
#            1       0.89      0.68      0.77        47
#
#     accuracy                           1.00     28298
#    macro avg       0.94      0.84      0.89     28298
# weighted avg       1.00      1.00      1.00     28298
#
# GBC_SMOTE_Robust:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     28251
#            1       0.23      0.77      0.35        47
#
#     accuracy                           1.00     28298
#    macro avg       0.62      0.88      0.68     28298
# weighted avg       1.00      1.00      1.00     28298
#
# GBC_Under_Sampling_Power:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     28251
#            1       0.22      0.77      0.34        47
#
#     accuracy                           0.99     28298
# ...

# %%
#Displaying Deep Learning (Artificial Neural Network)on Credit Card Fraud Detection 

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# Load dataset
df = pd.read_csv("creditcard.csv")

# Separate features and target variable
X = df.drop(columns=['Class'])
y = df['Class']

# Normalize features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Split dataset
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# Build ANN model
model = Sequential([
    Dense(32, activation='relu', input_shape=(X_train.shape[1],)),
    Dropout(0.3),
    Dense(16, activation='relu'),
    Dropout(0.3),
    Dense(1, activation='sigmoid')  # Binary classification
])

# Compile model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train model
history = model.fit(X_train, y_train, epochs=20, batch_size=32, validation_data=(X_test, y_test))

# Evaluate model
loss, accuracy = model.evaluate(X_test, y_test)
print(f"Test Accuracy: {accuracy:.4f}")
# Out:
# C:\Users\bosea\Credit Card Fraud Detection\virtual_env_name\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/20
# 7121/7121 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step - accuracy: 0.9974 - loss: 0.0284 - val_accuracy: 0.9992 - val_loss: 0.0039
# Epoch 2/20
# 7121/7121 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step - accuracy: 0.9990 - loss: 0.0053 - val_accuracy: 0.9994 - val_loss: 0.0034
# Epoch 3/20
# 7121/7121 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step - accuracy: 0.9992 - loss: 0.0039 - val_accuracy: 0.9993 - val_loss: 0.0035
# Epoch 4/20
# 7121/7121 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step - accuracy: 0.9993 - loss: 0.0035 - val_accuracy: 0.9994 - val_loss: 0.0035
# Epoch 5/20
# ...

# %%
#Displaying Confusion Matrix based on Deep Learning (Artificial Neural Network) 

import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import roc_curve, auc, confusion_matrix, ConfusionMatrixDisplay

# Get model predictions
y_prob = model.predict(X_test)  # Predicted probabilities
y_pred = (y_prob > 0.5).astype(int)  # Convert probabilities to binary labels

# Compute confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Display confusion matrix
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=[0, 1])
disp.plot(cmap=plt.cm.Blues)
plt.title("Confusion Matrix")
plt.show()
# Out:
# 1781/1781 ━━━━━━━━━━━━━━━━━━━━ 1s 467us/step

# %%
# Compute ROC curve and AUC based on Deep Learning (Artificial Neural Network) 
fpr, tpr, _ = roc_curve(y_test, y_prob)
roc_auc = auc(fpr, tpr)

# Plot ROC Curve
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='blue', lw=2, label=f'ROC curve (AUC = {roc_auc:.4f})')
plt.plot([0, 1], [0, 1], color='gray', linestyle='--')  # Random guess line
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()

# %%
#Displaying Classification Report based on Deep Learning (Artificial Neural Network) 

from sklearn.metrics import classification_report

# Generate classification report
report = classification_report(y_test, y_pred, target_names=["Non-Fraud (0)", "Fraud (1)"])

# Print the report
print(report)
# Out:
#                precision    recall  f1-score   support
#
# Non-Fraud (0)       1.00      1.00      1.00     56864
#     Fraud (1)       0.93      0.68      0.79        98
#
#      accuracy                           1.00     56962
#     macro avg       0.97      0.84      0.89     56962
#  weighted avg       1.00      1.00      1.00     56962
